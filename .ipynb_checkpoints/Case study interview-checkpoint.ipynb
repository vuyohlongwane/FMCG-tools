# %% [markdown]
# # Vuyo Hlongwane, Data Visualisation Case study
#
#
# ![Capture%201.PNG](attachment:Capture%201.PNG)
#
#
# If (1.) -> (2.) are accurate and do not *spike* often it can be seen that the pertubations in the system will be caused by sourcing unit internal barriers. The Image above shows the overall supply proccess through the sourcing unit.
#
# The visualisations that follow aim to better illustrate to the viewer: which are the lines that are not perfroming and then to be able to see what the issues are and with which formulations/products/SKU.
#
# This will unlock: -Immediate excess to data. Available in computable formats like .xlsx, .xls, .pdf, .png, .jpeg etc.
#
# ![image.png](attachment:image.png)
#
# Here is the raw data currently collected on site at Indonsa.
#
# ![B5.jpeg](attachment:B5.jpeg)

# %%
import numpy as np
import pandas as pd
import os
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from pandas.plotting import radviz


plt.close("all")



os.getcwd()
os.chdir('C:\\Users\\vuyo-minenhle.hlongw\\Downloads')

PVA_Unit_2=pd.read_excel("Copy of 42K-UNIT 2 -ACTION TRACKER.xlsx",index_col=1,
                         sheet_name=1)
print(type(PVA_Unit_2))

data_array=np.array(PVA_Unit_2)

PVA_type=data_array[:][1]


PVA_df=pd.DataFrame(data=PVA_Unit_2,columns=PVA_type)



Rdata={
    "TOTAL":[88,	97, 95,	95,	92,	103,	117,	98,	65,	67,	58.17,	68.21,	67,	66, 70,74],
    "Corazza 1": [86,	98,	46,	61,	62,	75,	89,	100,	54,	53,	32,	43,	43,	52,	61,	52],
    "Corazza 2": [79,	62,	62,	75,	77,	0	,0,	40,	48,	38,	43,	52,	53,	0,	0,	29],
    "Corazza 7": [84,	101,	104,	96,	98,	123,	107,	100,	59,	74,	75,	75,	76,	73,	83,	79],
    "Corazza 8": [84,	101,	92,	84,	84,	127,	100,	100,	60,	73,	65,	65,	66,	66,	78,	70],
    "Turra 1": [91,	102,	115,	85,	64,	104,	500,	104,	65,	58,	74,	60,	45,	73,	75,	66],
    "Turra 2": [89,	100,	74,	98,	99,	101,	98,	100,	72,	80,	60,	79,	80,	81,	79,	86],
    "Benhill 1": [88,	101,	120,	116,	105,	108,	100,	105,	62,	81,	84,	82,	81,	83,	77,	91],
    "Benhill 2": [86,	102,	138,	99,	99,	100,	102,	102,	67,	77,	35,	76,	76,	77,	79,	81],
    "Benhill 3": [86,	101,	108,	103,	95,	99,	109,	105,	72,	79,	76,	73,	73,	76,	84,	86],
    "Benhill 4": [88,	105,	137,	101,	102,	100,	97,	105,	67,	76,	51,	76,	77,	75,	73,	79],
    "Benhill 5": [94,	100,	102,	146,	140,	127,	165,	100,	67,	67,	36,	52,	50,	49,	59,	61],
    "Benhill 6": [91,	100,	88,	104,	100,	126,	106,	100,	71,	79,	69,	82,	79,	80,	84,	83],
    "Benhill 7": [92,	101,	90,	98,	93,	101,	104,	102,	69,	77,	61,	66,	63,	69,	71,	87],
    "Benhill 8": [89,	88,	91,	93,	101,	93,	97,	91,	65,	69,	52,	74,	80,	73,	77,	77]
    }

Indcz=["TOTAL","Corazza 1","Corazza 2","Corazza 7","Corazza 8","Turra 1","Turra 2","Benhill 1",
       "Benhill 2","Benhill 3","Benhill 4","Benhill 5","Benhill 6","Benhill 7","Benhill 8"]
time=['YTD',	'MTD',	'Mon', 	'Tue',	'Wed',	'Thu', '	Fri',	'WTD',	'YTDoee',	'MTD',	'Mon', 	'Tue',	'Wed',	'Thu',	'Fri',	'WTDoee']

d=pd.DataFrame(index=time,data=Rdata, columns = Indcz)

reporting='YTD'


d_transposed=d.transpose()
#print(d_transposed)

v=["Benhill 1","Benhill 2","Benhill 3","Benhill 4","Benhill 5","Benhill 6","Benhill 7","Benhill 8"]

size=[d_transposed[reporting]["Benhill 1"],d_transposed[reporting]["Benhill 2"], d_transposed[reporting]["Benhill 3"], d_transposed[reporting]["Benhill 4"], d_transposed[reporting]["Benhill 5"], 
                 d_transposed[reporting]["Benhill 6"],d_transposed[reporting]["Benhill 7"], 
                     d_transposed[reporting]["Benhill 8"]]

fig = go.Figure(data=[go.Scatter(
    x=[2, 9, 16, 4, 5, 8, 12, 3], y=[40, 8, 11, 2,15, 1, 69, 31],
     text=size,
    #[Indcz[7],Indcz[8],Indcz[9],Indcz[10],Indcz[11],Indcz[12],Indcz[13],Indcz[14]],
    mode='markers',
    marker=dict(
        size=size,
        sizemode='area',
        sizeref=2.*max(size)/(40.**2),
        sizemin=4,        
        color=size,
        showscale=True,
        opacity=[1, 0.8, 0.6, 0.4]
        
    )
)])


fig.update_layout(
    title='Cubes PVA v. Losses, Week 28 2019',
    xaxis=dict(
        title='MTD Line speed losses (h)',
        gridcolor='white',
        gridwidth=2,
    ),
    yaxis=dict(
        title='MTD line stopages (count)',
        gridcolor='white',
        gridwidth=2,
    ),
    paper_bgcolor='rgb(243, 243, 243)'
)


fig.show()



#radviz(d_transposed,"WTD")
#pd.plotting.scatter_matrix(d, alpha=0.5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
data1=[['Beef Curry',	6,	'B2'],
['Beef Curry',	2,	'B3'],
['Beef Curry',	6,	'B3'],
['Beef',	3,	'B3'],
['Beef',	10,	'B5'],
['Beef',	69,	'B7'],
['Chicken',	5,	'B5'],
['Beef Curry',	4.00,	'B4'],
['Beef',	5.00,	'B6'],
['Chilli Beef',	6.00,	'B8']]


d1=pd.DataFrame(data=data1, columns = ['Variant','Time', 'Machine'])


size=d1['Time']
fig = go.Figure(data=[go.Scatter(
    x=d1['Variant'], y=d1['Machine'],
     text=d1['Time'],
    mode='markers',
    marker=dict(
        size=size,
        sizemode='area',
        sizeref=2.*max(size)/(40.**2),
        sizemin=4,        
        color=size,
        showscale=True,
        opacity=[1, 0.8, 0.6, 0.4]
        
    )
)])


fig.update_layout(
    title='Cubes PVA v. Losses, Week 28 2019',
    xaxis=dict(
        title='MTD Line speed losses (h)',
        gridcolor='white',
        gridwidth=2,
    ),
    yaxis=dict(
        title='MTD line stopages (count)',
        gridcolor='white',
        gridwidth=2,
    ),
    paper_bgcolor='rgb(243, 243, 243)'
)


fig.show()
# Out:
# <div>                            <div id="0a76580b-bf7b-438e-bd57-ead47e80ab36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a76580b-bf7b-438e-bd57-ead47e80ab36")) {                    Plotly.newPlot(                        "0a76580b-bf7b-438e-bd57-ead47e80ab36",                        [{"marker": {"color": [6.0, 2.0, 6.0, 3.0, 10.0, 69.0, 5.0, 4.0, 5.0, 6.0], "opacity": [1, 0.8, 0.6, 0.4], "showscale": true, "size": [6.0, 2.0, 6.0, 3.0, 10.0, 69.0, 5.0, 4.0, 5.0, 6.0], "sizemin": 4, "sizemode": "area", "sizeref": 0.08625}, "mode": "markers", "text": [6.0, 2.0, 6.0, 3.0, 10.0, 69.0, 5.0, 4.0, 5.0, 6.0], "type": "scatter", "x": ["Beef Curry", "Beef Curry", "Beef Curry", "Beef", "Beef", "Beef", "Chicken", "Beef Curry", "Beef", "Chilli Beef"], "y":
# ...
